# %%
import urllib
import json


xray_pdb_json_query = '{"query":{"type":"terminal","label":"text","service":"text","parameters":{"attribute":"exptl.method","operator":"exact_match","negation":false,"value":"X-RAY DIFFRACTION"}},"return_type":"entry","request_options":{"scoring_strategy":"combined","sort":[{"sort_by":"score","direction":"desc"}]}}'

pdb_json = json.loads(xray_pdb_json_query)

test = urllib.parse.urlencode(pdb_json)

# %%
my_json_query = '{"query":{"type":"terminal","label":"text","service":"text","parameters":{"attribute":"exptl.method","operator":"exact_match","negation":false,"value":"X-RAY DIFFRACTION"}},"return_type":"entry","request_options":{"scoring_strategy":"combined","sort":[{"sort_by":"score","direction":"desc"}]}}'

# %%
import random

def ant_walk():
    timer = 0
    ant = [0,0,0]
    while ant != [1,1,1]:
        ant[random.randrange(3)] ^= 1 #XOR bitwise swap b/t 0 and 1
        timer +=1
    
    print(timer)
    
ant_walk()
# Out:
# 3

# %%
times = []

for _ in range(1000):
    times.append(ant_walk())
# Out:
# 21
# 3
# 7
# 7
# 3
# 3
# 11
# 3
# 5
# 11
# 7
# 5
# 3
# 9
# 9
# 5
# 5
# 33
# 15
# 3
# 9
# 29
# 9
# 3
# 3
# 3
# 19
# 3
# 17
# 3
# 3
# 11
# 5
# 5
# 23
# 25
# 3
# 5
# 3
# 17
# 5
# 13
# 3
# 25
# 23
# 7
# 13
# 7
# 7
# 3
# 5
# 15
# 5
# 5
# 7
# 13
# 17
# 27
# 3
# 5
# 3
# 7
# 11
# 11
# 3
# 7
# 13
# 3
# 21
# 9
# 13
# 7
# 7
# 5
# 9
# 25
# 21
# 5
# 7
# 7
# 13
# 5
# 9
# 11
# 7
# 19
# 7
# 7
# 3
# 5
# 9
# 11
# 7
# 13
# 5
# 3
# 13
# 3
# 5
# 3
# 13
# 13
# 3
# 3
# 31
# 3
# 9
# 15
# 23
# 7
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 27
# 3
# 3
# 5
# 7
# 5
# 5
# 29
# 3
# 11
# 37
# 11
# 13
# 17
# 3
# 9
# 15
# 11
# 11
# 5
# 15
# 15
# 13
# 3
# 21
# 15
# 39
# 15
# 15
# 3
# 11
# 11
# 7
# 13
# 5
# 9
# 3
# 11
# 43
# 25
# 15
# 7
# 21
# 7
# 15
# 21
# 17
# 23
# 7
# 9
# 3
# 19
# 7
# 5
# 9
# 7
# 7
# 3
# 9
# 3
# 7
# 5
# 7
# 5
# 3
# 11
# 5
# 7
# 9
# 3
# 9
# 3
# 15
# 7
# 11
# 9
# 15
# 3
# 21
# 13
# 41
# 7
# 3
# 3
# 9
# 11
# 3
# 19
# 5
# 3
# 5
# 29
# 9
# 3
# 3
# 15
# 9
# 11
# 9
# 13
# 5
# 5
# 15
# 7
# 21
# 3
# 11
# 7
# 7
# 5
# 5
# ...

# %%
import numpy as np

times.

# %%
my_json_query_dttime = f'%7B"query"%3A%7B"type"%3A"group"%2C"logical_operator"%3A"and"%2C"nodes"%3A%5B%7B"type"%3A"terminal"%2C"service"%3A"text"%2C"parameters"%3A%7B"attribute"%3A"exptl.method"%2C"operator"%3A"exact_match"%2C"negation"%3Afalse%2C"value"%3A"X-RAY%20DIFFRACTION"%7D%7D%2C%7B"type"%3A"terminal"%2C"service"%3A"text"%2C"parameters"%3A%7B"attribute"%3A"rcsb_accession_info.initial_release_date"%2C"operator"%3A"greater"%2C"negation"%3Afalse%2C"value"%3A"{date_str}"%7D%7D%5D%2C"label"%3A"text"%7D%2C"return_type"%3A"entry"%2C"request_options"%3A%7B"paginate"%3A%7B"start"%3A0%2C"rows"%3A100000%7D%2C"scoring_strategy"%3A"combined"%2C"sort"%3A%5B%7B"sort_by"%3A"score"%2C"direction"%3A"desc"%7D%5D%7D%7D'
my_json_query_dttime
